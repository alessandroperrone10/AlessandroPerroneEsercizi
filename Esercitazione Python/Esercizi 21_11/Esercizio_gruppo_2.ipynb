# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sc

# %%
#Percorso del file CSV
file_path = 'film.csv'

# Caricamneto dei dati nel DataFrame
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
# 2                  Welcome to a world without rules.
# 3                        Enter the world of Pandora.
# 4                            Some assembly required.
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords          directors  \
# 0  rescue, mission, dream, airplane, paris, franc...  Christopher Nolan
# 1  rescue, future, spacecraft, race against time,...  Christopher Nolan
# 2  joker, sadism, chaos, secret identity, crime f...  Christopher Nolan
# 3  future, society, culture clash, space travel, ...      James Cameron
# 4  new york city, superhero, shield, based on com...        Joss Whedon
#
#                                              writers averageRating numVotes
# 0                                  Christopher Nolan           8.8  2615046
# 1                  Jonathan Nolan, Christopher Nolan           8.7  2200215
# 2  Jonathan Nolan, Christopher Nolan, David S. Go...           9.0  2946971
# 3                                      James Cameron           7.9  1409099
# 4                              Joss Whedon, Zak Penn           8.0  1483869
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432295 entries, 0 to 432294
# Data columns (total 28 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    432295 non-null  int64
#  1   title                 432295 non-null  object
#  2   vote_average          432295 non-null  float64
#  3   vote_count            432295 non-null  int64
#  4   status                432295 non-null  object
#  5   release_date          414562 non-null  object
#  6   revenue               432295 non-null  int64
#  7   runtime               432295 non-null  int64
#  8   adult                 432295 non-null  bool
#  9   backdrop_path         183573 non-null  object
#  10  budget                432295 non-null  int64
#  11  homepage              54111 non-null   object
#  12  tconst                432295 non-null  object
#  13  original_language     432295 non-null  object
#  14  original_title        432295 non-null  object
#  15  overview              391238 non-null  object
#  16  popularity            432295 non-null  float64
#  17  poster_path           358326 non-null  object
#  18  tagline               90930 non-null   object
#  19  genres                355422 non-null  object
#  20  production_companies  262127 non-null  object
#  21  production_countries  321539 non-null  object
#  22  spoken_languages      331463 non-null  object
#  23  keywords              170701 non-null  object
#  24  directors             421940 non-null  object
#  25  writers               365214 non-null  object
#  26  averageRating         432295 non-null  float64
#  27  numVotes              432295 non-null  int64
# dtypes: bool(1), float64(3), int64(6), object(18)
# memory usage: 89.5+ MB

# %%
df.describe()
# Out:
#                  id   vote_average     vote_count       revenue  \
# count  4.322950e+05  432295.000000  432295.000000  4.322950e+05
# mean   4.781282e+05       3.624079      49.289115  1.648859e+06
# std    3.433845e+05       3.142025     515.011470  2.598421e+07
# min    2.000000e+00       0.000000       0.000000  0.000000e+00
# 25%    2.070075e+05       0.000000       0.000000  0.000000e+00
# 50%    4.133320e+05       4.700000       1.000000  0.000000e+00
# 75%    6.902115e+05       6.200000       6.000000  0.000000e+00
# max    1.390572e+06      10.000000   34495.000000  2.923706e+09
#
#              runtime        budget     popularity  averageRating      numVotes
# count  432295.000000  4.322950e+05  432295.000000  432295.000000  4.322950e+05
# mean       66.506976  6.409536e+05       2.215292       6.248331  2.814338e+03
# std        63.234720  7.125117e+06      11.391053       1.315747  3.167942e+04
# min         0.000000  0.000000e+00       0.000000       1.000000  5.000000e+00
# 25%        15.000000  0.000000e+00       0.600000       5.500000  2.000000e+01
# 50%        80.000000  0.000000e+00       0.866000       6.300000  5.900000e+01
# 75%        96.000000  0.000000e+00       1.673000       7.100000  2.620000e+02
# max     14400.000000  8.880000e+08    2994.357000      10.000000  2.965480e+06

# %%
df.averageRating
# Out:
# 0         8.8
# 1         8.7
# 2         9.0
# 3         7.9
# 4         8.0
#          ...
# 432290    7.1
# 432291    5.7
# 432292    7.4
# 432293    5.9
# 432294    7.4
# Name: averageRating, Length: 432295, dtype: float64

# %%
df.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
#        'tconst', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'keywords', 'directors', 'writers', 'averageRating', 'numVotes'],
#       dtype='object')

# %%
categorie_da_droppare = ['id','backdrop_path','homepage','tconst','poster_path','tagline']

df.drop()

# %%
lista = ['vote_average','budget','revenue','averageRating','popularity']

sns.pairplot(df[lista][df['budget']> 0][df['revenue']> 0][df['averageRating'] > 0], diag_kind='kde', plot_kws={'linewidth': 0, 'size': 0.1, 'alpha': 0.01})
plt.suptitle('Pair Plot del DataFrame per film', y=1.02)
plt.show()
# Out:
# /var/folders/xx/f3mw_zd11yv2thln0zygp7hc0000gn/T/ipykernel_4295/1131683528.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.pairplot(df[lista][df['budget']> 0][df['revenue']> 0][df['averageRating'] > 0], diag_kind='kde', plot_kws={'linewidth': 0, 'size': 0.1, 'alpha': 0.01})
# /var/folders/xx/f3mw_zd11yv2thln0zygp7hc0000gn/T/ipykernel_4295/1131683528.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.pairplot(df[lista][df['budget']> 0][df['revenue']> 0][df['averageRating'] > 0], diag_kind='kde', plot_kws={'linewidth': 0, 'size': 0.1, 'alpha': 0.01})

# %%
df['averageRating'].unique()
# Out:
# array([ 8.8,  8.7,  9. ,  7.9,  8. ,  8.4,  8.9,  7.6,  8.5,  9.3,  8.2,
#         7.3,  7.8,  7.1,  7.5,  8.1,  7.2,  7.4,  6.9,  5.9,  7. ,  8.6,
#         7.7,  8.3,  9.2,  6.5,  6.7,  6.8,  6.4,  6.6,  6.3,  5.3,  6.1,
#         5.8,  4.2,  6.2,  5.7,  4.8,  5.2,  3.3,  5.6,  4.9,  5.1,  6. ,
#         5.4,  5.5,  4.5,  4.6,  4.3,  3.8,  5. ,  4. ,  3.4,  3.5,  4.4,
#         4.7,  2.5,  2.3,  2.8,  4.1,  2.4,  3.9,  3.6,  2.7,  3.1,  3.7,
#         2.6,  1.9,  3. ,  2.9,  2. ,  3.2,  1.7,  2.2,  2.1,  1.8,  1.6,
#         9.1,  1.5,  1.3,  9.4,  1.4, 10. ,  1.2,  1. ,  1.1,  9.6,  9.7,
#         9.5,  9.8,  9.9])

# %%
df['vote_average'].unique()
# Out:
# array([8.364, 8.417, 8.512, ..., 1.333, 0.5  , 0.75 ])

# %%
df[df['budget'] == 0]
# Out:
#             id                              title  vote_average  vote_count  \
# 258     372058                         Your Name.         8.514       10303
# 375     664413                           365 Days         7.063        8429
# 395     466282  To All the Boys I've Loved Before         7.642        8045
# 509     454983                  The Kissing Booth         7.229        6926
# 652     200727                        Love, Rosie         7.837        5918
# ...        ...                                ...           ...         ...
# 432289  732525                        Drama Queen         0.000           0
# 432290  732467                   One Pandemic Day         0.000           0
# 432291  732477            The Men Who Speak Gayle         0.000           0
# 432292  732485                         Conversion         0.000           0
# 432293  732486                     Shukran Habibi         0.000           0
#
#           status release_date    revenue  runtime  adult  \
# 258     Released   2016-08-26  357986087      106  False
# 375     Released   2020-02-07    9458590      116  False
# 395     Released   2018-08-16          0      100  False
# 509     Released   2018-05-11          0      105  False
# 652     Released   2014-10-16    4439431      102  False
# ...          ...          ...        ...      ...    ...
# 432289  Released   2020-02-14          0       90  False
# 432290  Released          NaN          0      117  False
# 432291  Released   2020-07-15          0       11  False
# 432292  Released   2021-06-26          0       66  False
# 432293  Released   2020-01-03          0       35  False
#
#                            backdrop_path  ...  \
# 258     /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg  ...
# 375     /isBjNHBblzxrzHrAtRbjgkYzAut.jpg  ...
# 395     /xXhta1NIKn09IXy0mfp68cabdWS.jpg  ...
# 509     /aqrDUkuzksLhOD8pbyBXLO0dz5t.jpg  ...
# 652     /txDX7lBx8bBhF7dRCEfDYmAmdnk.jpg  ...
# ...                                  ...  ...
# 432289  /cInsR3sXx6t97eUTbGyv3W9in9p.jpg  ...
# 432290                               NaN  ...
# 432291                               NaN  ...
# 432292                               NaN  ...
# 432293                               NaN  ...
#
#                                                   tagline  \
# 258     It was almost like seeing something out of a d...
# 375                                                   NaN
# 395                                  The letters are out.
# 509     She can tell her best friend anything, except ...
# 652                               Right Love. Wrong Time.
# ...                                                   ...
# 432289                                                NaN
# 432290         It's a normal day, 35 days into a pandemic
# 432291                                                NaN
# 432292  How two unlikely friends change the world for ...
# 432293                                                NaN
#
#                            genres  \
# 258     Romance, Animation, Drama
# 375                Romance, Drama
# 395               Comedy, Romance
# 509               Romance, Comedy
# 652        Romance, Drama, Comedy
# ...                           ...
# 432289                     Comedy
# 432290                Documentary
# 432291                Documentary
# 432292                        NaN
# 432293                        NaN
#
#                                      production_companies  \
# 258     CoMix Wave Films, TOHO, KADOKAWA, East Japan M...
# 375             Ekipa, Future Space, Next Film, TVN Group
# 395            Awesomeness Films, Overbrook Entertainment
# 509                                  Komixx Entertainment
# 652     Constantin Film, Octagon Films, Canyon Creek F...
# ...                                                   ...
# 432289                                                NaN
# 432290                           Film.Ca Productions Inc.
# 432291                                      Caspian Films
# 432292                                                NaN
# 432293                                                NaN
#
#                                      production_countries  \
# 258                                                 Japan
# 375                                                Poland
# 395                              United States of America
# 509                                        United Kingdom
# 652     Belgium, Canada, Germany, Ireland, United Kingdom
# ...                                                   ...
# 432289                                                NaN
# 432290                                                NaN
# 432291                       South Africa, United Kingdom
# 432292                                                NaN
# 432293                                                NaN
#
#                         spoken_languages  \
# 258                             Japanese
# 375     English, French, Italian, Polish
# 395                              English
# 509                              English
# 652                              English
# ...                                  ...
# 432289                               NaN
# 432290                               NaN
# 432291                Afrikaans, English
# 432292                           English
# 432293                               NaN
#
#                                                  keywords  \
# 258     race against time, afterlife, natural disaster...
# 375     kidnapping, gangster, yacht, nightclub, mansio...
# 395     high school, based on novel or book, love lett...
# 509     based on novel or book, crush, los angeles, ca...
# 652     friendship, based on novel or book, love, best...
# ...                                                   ...
# 432289                                                NaN
# 432290                                 pandemic, covid-19
# 432291                           drag queen, south africa
# 432292                                                NaN
# 432293                                                NaN
#
#                               directors  \
# 258                      Makoto Shinkai
# 375     Barbara Bialowas, Tomasz Mandes
# 395                       Susan Johnson
# 509                      Vince Marcello
# 652                    Christian Ditter
# ...                                 ...
# 432289                       Kay Nguyen
# 432290                    Mikelle Virey
# 432291                   Andrew Brukman
# 432292                   Gregory Caruso
# 432293                     Ville Tanttu
#
#                                                   writers averageRating  \
# 258                                        Makoto Shinkai           8.4
# 375     Tomasz Klimala, Tomasz Mandes, Barbara Bialowa...           3.3
# 395                              Sofia Alvarez, Jenny Han           7.0
# 509                          Vince Marcello, Beth Reekles           5.9
# 652                       Juliette Towhidi, Cecelia Ahern           7.1
# ...                                                   ...           ...
# 432289                                         Kay Nguyen           5.5
# 432290                                                NaN           7.1
# 432291                                     Nathan Kennedy           5.7
# 432292                                                NaN           7.4
# 432293                                       Ville Tanttu           5.9
#
#        numVotes
# 258      338912
# 375      101334
# 395      128159
# 509       96486
# 652      159387
# ...         ...
# 432289       31
# 432290       25
# 432291        8
# 432292       39
# 432293        8
#
# [403374 rows x 28 columns]

# %%
#filtro su budget, revenue e vote_avarage,
